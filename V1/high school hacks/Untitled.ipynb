# %%
import numpy as np
import pandas as pd
import requests
import xlsxwriter
import math 
import yfinance as yf
import urllib.parse

# %%
stocks = pd.read_csv('sp_500_stocks.csv')
stocks
# Out:
#     Ticker
# 0        A
# 1      AAL
# 2      AAP
# 3     AAPL
# 4     ABBV
# ..     ...
# 500    YUM
# 501    ZBH
# 502   ZBRA
# 503   ZION
# 504    ZTS
#
# [505 rows x 1 columns]

# %%
api_key = 'A4XHTZWKU4Z14AUJ'
symbol = 'AAPL'
api_url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={symbol}&apikey={api_key}'
data_generic = requests.get(api_url).json()

# %%
price = data_generic.get('Global Quote', {}).get('05. price')
api_url_overview = f'https://www.alphavantage.co/query?function=OVERVIEW&symbol={symbol}&apikey={api_key}'
data_overview = requests.get(api_url_overview).json()
market_cap = data_overview['MarketCapitalization']
api_url_overview
market_cap
# Out:
# '2759285801000'

# %%
my_columns = ['Ticker', 'Stock Price', 'Market Cap', 'Number of Shares to Buy']
final_dataframe = pd.DataFrame(columns=my_columns)
final_dataframe
# Out:
# Empty DataFrame
# Columns: [Ticker, Stock Price, Market Cap, Number of Shares to Buy]
# Index: []

# %%
final_dataframe.append(
    pd.Series(
    [
            symbol,
            price,
            market_cap,
            'N/A'
    ]
    ),
    ignore_index = True
)
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_18028\3228661043.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe.append(
#   Ticker Stock Price Market Cap Number of Shares to Buy     0         1  \
# 0    NaN         NaN        NaN                     NaN  AAPL  175.4300
#
#                2    3
# 0  2759285801000  N/A

# %%
final_dataframe = pd.DataFrame(columns=my_columns)
for stock in stocks['Ticker']:
    api_url_overview = f'https://www.alphavantage.co/query?function=OVERVIEW&symbol={stock}&apikey={api_key}'
    data_overview = requests.get(api_url_overview).json()
    final_dataframe = final_dataframe.append(
        pd.Series(
            [
                stock,
                data_generic.get('Global Quote', {}).get('05. price'),
                market_cap,
                'N/A'
            ],
            index=my_columns
        ),
        ignore_index=True
    )
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_18028\189165054.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\David\AppData\Local\Temp\ipykernel_18028\189165054.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\David\AppData\Local\Temp\ipykernel_18028\189165054.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# C:\Users\David\AppData\Local\Temp\ipykernel_18028\189165054.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe = final_dataframe.append(
# ...

# %%
final_dataframe
# Out:
#     Ticker Stock Price     Market Cap Number of Shares to Buy
# 0        A    175.4300  2759285801000                     N/A
# 1      AAL    175.4300  2759285801000                     N/A
# 2      AAP    175.4300  2759285801000                     N/A
# 3     AAPL    175.4300  2759285801000                     N/A
# 4     ABBV    175.4300  2759285801000                     N/A
# ..     ...         ...            ...                     ...
# 500    YUM    175.4300  2759285801000                     N/A
# 501    ZBH    175.4300  2759285801000                     N/A
# 502   ZBRA    175.4300  2759285801000                     N/A
# 503   ZION    175.4300  2759285801000                     N/A
# 504    ZTS    175.4300  2759285801000                     N/A
#
# [505 rows x 4 columns]

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
symbol_groups = list(chunks(stocks['Ticker'], 100))
symbol_strings = []
for i in range(0, len(symbol_groups)):
    symbol_strings.append(','.join(symbol_groups[i]))

final_dataframe = pd.DataFrame(columns=my_columns)
for symbol_string in symbol_strings:
    batch_api_call_url = f'https://www.alphavantage.co/batch?function=OVERVIEW&symbols={symbol_string}&apikey={api_key}'
    data_generic = requests.get(batch_api_call_url).json()
    for symbol in symbol_string.split(','):
        final_dataframe = final_dataframe.append(
            pd.Series(
                [
                    symbol,
                    data_generic[symbol]['Global Quote']['05. price'],
                    data_overview[symbol]['MarketCapitalization'],
                    'N/A',
                ],
                index=my_columns
            ),
            ignore_index=True
        )

final_dataframe
